# %% [markdown]
# ## **1. Contexto Dataset**

# %% [markdown]
# ### **Descripción de columnas - Dataset Cierres Cartera**

# %% [markdown]
# ##### Identificadores y datos de la operación
# - *NUMERO DE LA COLOCACION2*: Código o consecutivo único del crédito o préstamo.
# - *NUMERO DE IDENTIFICACION DEUDOR*: Documento del cliente titular del crédito.
# - *NUMERO DEL PRODUCTO*: Código del tipo de producto financiero otorgado.
# - *NUMERO DE LA AGENCIA*: Código de la sucursal o agencia donde se gestionó el crédito.
#
# ---
#
# ##### Información del crédito
# - *PLAZO UNIDAD TIEMPO*: Número de cuotas o duración del crédito en una unidad de tiempo (ej. meses).
# - *PLAZO EN DIAS*: Plazo total del crédito expresado en días.
# - *NUMERO DE PAGOS PACTA*: Cantidad de pagos acordados al inicio del crédito.
# - *VALOR ORIGINAL DEL PR**: Monto del préstamo otorgado inicialmente.
# - *CAPITAL PEND POR FACT*: Valor del capital aún pendiente por facturar.
# - *SALDO DEL PRESTAMO*: Monto actual pendiente de pago del préstamo.
#
# ---
#
# ##### Fechas importantes
# - *FECHA APERTURA DEL PR*: Fecha de apertura o formalización del crédito.
# - *FECHA DE DESEMBOLS*: Fecha en la que se hizo efectivo el desembolso.
# - *FEC CUOTA MAS ANTIG PENDIENTE DE PAGO*: Fecha de la cuota más antigua que aún no ha sido pagada.
# - *FEC PROX PAGO*: Fecha programada para el siguiente pago.
# - *FECHA EFEC ULTIMO PAGO*: Fecha en la que se realizó el último pago.
# - *FECHA DE NACIMIENTO TITULAR*: Fecha de nacimiento del cliente.
#
# ---
#
# ##### Estado de pagos y comportamiento
# - *NRO PLAN PAGOS VIGENT*: Cantidad de planes de pago aún vigentes.
# - *NRO DE UTILIZACINES D*: Veces que se ha utilizado algún beneficio o línea de crédito (columna poco clara, revisar ortografía).
# - *DIAS DE MORA*: Número de días que lleva en mora el cliente.
# - *CALIFICACION CARTERA*: Clasificación del crédito según el nivel de riesgo o mora (ej. A, B, C...).
# - *VLR ULTIMO PAGO*: Valor del último pago realizado por el cliente.
# - *VLR TASA*: Valor o porcentaje de la tasa de interés aplicada.
# - *VLR CUOTA MES*: Valor mensual que debe pagar el cliente (cuota pactada).
# - *VLR MINIMO DE PAGO*: Monto mínimo que puede pagar para evitar mora.
# - *DIA VENCIMIENTO CUOTA*: Día del mes en que vence la cuota.
# - *NRO CUOTAS VENCIDAS*: Número total de cuotas vencidas hasta la fecha.
# - *NRO CUOTAS PAGADAS*: Cuotas ya pagadas por el cliente.
# - *NRO CUOTAS RESTANTE*: Cuotas aún pendientes de pago.
# - *VALOR CUOTAS VENCIDAS*: Suma de las cuotas vencidas.
# - *VALOR CAPITAL CUOTAS VENCIDAS*: Parte de capital dentro de las cuotas vencidas.
#
# ---
#
# ##### Datos del cliente
# - *ESTADO CIVIL*: Estado civil declarado al momento del estudio.
# - *SEXO*: Género del cliente.
# - *EDAD DEL CLIENTE*: Edad actual del cliente.
# - *ESTADO CIVIL.1*: Posible actualización o duplicado del estado civil.
# - *NUMERO DE PERSONAS A CARGO*: Personas que dependen económicamente del cliente.
# - *INGRESOS*: Ingreso mensual declarado del cliente.
# - *OCUPACIÓN*: Actividad laboral del cliente (comerciante, empleado, etc.).
# - *ANTIGÜEDAD LABORAL*: Tiempo (en meses) que lleva el cliente trabajando.
# - *NIVEL DE ESTUDIOS*: Nivel educativo alcanzado.
# - *TIPO DE VIVIENDA*: Tipo de vivienda (propia, arrendada, familiar).
#
# ---
#
# ##### Vehículo financiado (si aplica)
# - *CIUDAD VITRINA*: Ciudad donde se ofreció o entregó el vehículo.
# - *MARCA / MARCA.1*: Marca del vehículo adquirido.
# - *LINEA*: Línea o modelo específico del vehículo.
# - *CLASE*: Tipo de vehículo (camión, carro, moto, etc.).
# - *MODELO*: Año del modelo del vehículo.
# - *SERVICIO / TIPO DE SERVICIO*: Uso del vehículo (particular, público).
# - *TIPO DE VEHICULO*: Si es nuevo, usado, demo, etc.
# - *VALOR COMERCIAL*: Valor de mercado del vehículo financiado.
#
# ---
#
# ##### Otros datos
# - *NUMERO DE SOLICITUD TITULAR*: Código único de la solicitud original del crédito.
# - *PERFIL DEL TITULAR*: Perfil o segmento del cliente según la entidad.
# - *VALOR SOLICITADO*: Monto solicitado por el cliente al inicio del proceso.
# - *ASESOR DE DESEMBOLSO / ASESOR DE VENTAS*: Persona responsable del crédito o venta.
# - *TASA DE MORA*: Porcentaje aplicado al saldo vencido en caso de mora.
# - *TIPO DE ID*: Tipo de documento (CC, CE, NIT, etc.).
# - *TIPO DE SOLICITANTE*: Titular, codeudor, etc.
# - *ACIERTA*: Valor asociado a scoring crediticio (evaluación automática).
# - *PRODUCTO*: Tipo de producto, por ejemplo: cartera castigada, normal, reestructurada, etc.

# %% [markdown]
# ### **Librerías**

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Carga del archivo Excel**

# %%
# Usando ruta absoluta
ruta_cierre = r"C:\Users\USER\OneDrive - universidadean.edu.co\2. Semestre\Seminario de investigación\Modulo 2\Modelo ML\data\raw\consolidado_cierres_Mod.xlsx"
df_cartera = pd.read_excel(ruta_cierre)

# Mostrar las primeras filas
df_cartera
# Out:
#        NUMERO DE LA COLOCACION  NUMERO DE IDENTIFICACION DEUDOR  \
# 0                           90                         52743777
# 1                          148                         80138994
# 2                          185                       1020770824
# 3                          189                       1073671165
# 4                          199                       1013601031
# ...                        ...                              ...
# 45006            5011001000085                         16931846
# 45007            6011001000003                         19156617
# 45008            6011001000023                         18492718
# 45009            6011014000001                         19156617
# 45010            8011001000020                         79762099
#
#        NUMERO DEL PRODUCTO  NUMERO DE LA AGENCIA  PLAZO UNIDAD TIEMPO  \
# 0                      905                   223                   72
# 1                      905                   222                   60
# 2                      905                   203                   60
# 3                        9                   221                   72
# 4                        9                   223                   54
# ...                    ...                   ...                  ...
# 45006                  905                   501                   82
# 45007                  900                   601                   60
# 45008                  905                   601                   84
# 45009                  902                   601                   12
# 45010                  905                   801                   48
#
#        PLAZO EN DIAS  NUMERO DE PAGOS PACTA UNIDAD DE TIEMPO  \
# 0               2160                     72                M
# 1               1800                     60                M
# 2               1800                     60                M
# 3               2160                     72                M
# 4               1620                     51                M
# ...              ...                    ...              ...
# 45006           2460                     82                M
# 45007           1800                     60                M
# 45008           2520                     84                M
# 45009            360                     12                M
# 45010           1440                     48                M
#
#        VALOR ORIGINAL DEL PR  CAPITAL PEND POR FACT  ...  ACIERTA  \
# 0                   50000000                    0.0  ...        0
# 1                   42850000                    0.0  ...        0
# 2                   33975000                    0.0  ...        0
# 3                   31320000                    0.0  ...        0
# 4                   53606700              8830472.8  ...        0
# ...                      ...                    ...  ...      ...
# 45006               44541000                    0.0  ...        0
# 45007               37800000                    0.0  ...        0
# 45008               35775000                    0.0  ...        0
# 45009                1741963                    0.0  ...        0
# 45010               16110000                    0.0  ...        0
#
#        TIPO DE VIVIENDA  ANTIGÜEDAD LABORAL   ESTADO CIVIL  \
# 0              FAMILIAR                  60    UNION LIBRE
# 1              FAMILIAR                  50    UNION LIBRE
# 2              FAMILIAR                   9        SOLTERO
# 3             ARRENDADA                  60    UNION LIBRE
# 4              FAMILIAR                  48        SOLTERO
# ...                 ...                 ...            ...
# 45006       NO REGISTRA                   0  NO REGISTRADO
# 45007       NO REGISTRA                   0  NO REGISTRADO
# 45008       NO REGISTRA                   0  NO REGISTRADO
# 45009       NO REGISTRA                   0  NO REGISTRADO
# 45010       NO REGISTRA                   0  NO REGISTRADO
#
#        NUMERO DE PERSONAS A CARGO  INGRESOS  TIPO DE VEHICULO  \
# 0                               0   6800000             NUEVO
# 1                               0   7650000             NUEVO
# 2                               0   3516860             NUEVO
# 3                               2   5000000             NUEVO
# 4                               0  14800000             NUEVO
# ...                           ...       ...               ...
# 45006                           0         0              OTRO
# 45007                           0         0              OTRO
# 45008                           0         0              OTRO
# 45009                           0         0              OTRO
# 45010                           0         0              OTRO
#
#        TIPO DE SERVICIO                    PRODUCTO  FECHA_CIERRE
# 0            PARTICULAR           CARTERA CASTIGADA    2024-01-31
# 1            PARTICULAR           CARTERA CASTIGADA    2024-01-31
# 2            PARTICULAR           CARTERA CASTIGADA    2024-01-31
# 3            PARTICULAR            VEHICULO CONSUMO    2024-01-31
# 4            PARTICULAR            VEHICULO CONSUMO    2024-01-31
# ...                 ...                         ...           ...
# 45006              OTRO           CARTERA CASTIGADA    2025-03-31
# 45007              OTRO            VEHICULO CASTIGO    2025-03-31
# 45008              OTRO           CARTERA CASTIGADA    2025-03-31
# 45009              OTRO  POLIZA TODO RIESGO CASTIGO    2025-03-31
# 45010              OTRO           CARTERA CASTIGADA    2025-03-31
#
# [45011 rows x 42 columns]

# %% [markdown]
# ### **Información general del dataset**

# %% [markdown]
# #### Informacion general por columna

# %%
df_cartera.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45011 entries, 0 to 45010
# Data columns (total 42 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   NUMERO DE LA COLOCACION                45011 non-null  int64
#  1   NUMERO DE IDENTIFICACION DEUDOR        45011 non-null  int64
#  2   NUMERO DEL PRODUCTO                    45011 non-null  int64
#  3   NUMERO DE LA AGENCIA                   45011 non-null  int64
#  4   PLAZO UNIDAD TIEMPO                    45011 non-null  int64
#  5   PLAZO EN DIAS                          45011 non-null  int64
#  6   NUMERO DE PAGOS PACTA                  45011 non-null  int64
#  7   UNIDAD DE TIEMPO                       45011 non-null  object
#  8   VALOR ORIGINAL DEL PR                  45011 non-null  int64
#  9   CAPITAL PEND POR FACT                  45011 non-null  float64
#  10  FECHA APERTURA DEL PR                  45011 non-null  int64
#  11  SALDO DEL PRESTAMO                     45011 non-null  float64
#  12  NRO PLAN PAGOS VIGENT                  45011 non-null  int64
#  13  NRO DE UTILIZACINES D                  44951 non-null  float64
#  14  DIAS DE MORA                           18768 non-null  float64
#  15  CALIFICACION CARTERA                   44767 non-null  object
#  16  FEC CUOTA MAS ANTIG PENDIENTE DE PAGO  44894 non-null  float64
#  17  FEC PROX PAGO                          45011 non-null  int64
#  18  FECHA EFEC ULTIMO PAGO                 42671 non-null  float64
#  19  VLR ULTIMO PAGO                        45011 non-null  float64
#  20  VLR TASA                               45011 non-null  float64
#  21  VLR CUOTA MES                          45011 non-null  int64
#  22  VLR MINIMO DE PAGO                     45011 non-null  float64
#  23  DIA VENCIMIENTO CUOTA                  45011 non-null  int64
#  24  NRO CUOTAS VENCIDAS                    18943 non-null  float64
#  25  NRO CUOTAS PAGADAS                     42867 non-null  object
#  26  NRO CUOTAS RESTANTE                    45002 non-null  float64
#  27  NIVEL DE ESTUDIOS                      45011 non-null  object
#  28  MARCA                                  45011 non-null  object
#  29  TIPO DE SOLICITANTE                    45011 non-null  object
#  30  TIPO DE ID                             45011 non-null  object
#  31  OCUPACIÓN                              45011 non-null  object
#  32  ACIERTA                                45011 non-null  int64
#  33  TIPO DE VIVIENDA                       45011 non-null  object
#  34  ANTIGÜEDAD LABORAL                     45011 non-null  int64
#  35  ESTADO CIVIL                           45011 non-null  object
#  36  NUMERO DE PERSONAS A CARGO             45011 non-null  int64
#  37  INGRESOS                               45011 non-null  int64
#  38  TIPO DE VEHICULO                       45011 non-null  object
#  39  TIPO DE SERVICIO                       45011 non-null  object
#  40  PRODUCTO                               45011 non-null  object
#  41  FECHA_CIERRE                           45011 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(11), int64(17), object(13)
# memory usage: 14.4+ MB

# %% [markdown]
# #### Estadisticas basicas de variables cuantitativas

# %%
df_cartera.describe()
# Out:
#        NUMERO DE LA COLOCACION  NUMERO DE IDENTIFICACION DEUDOR  \
# count             4.501100e+04                     4.501100e+04
# mean              1.087626e+11                     7.332382e+08
# min               9.000000e+01                     2.583320e+05
# 25%               6.431000e+03                     5.220616e+07
# 50%               8.820000e+03                     8.024925e+07
# 75%               1.045400e+04                     1.030679e+09
# max               8.011001e+12                     9.015700e+09
# std               5.525469e+11                     1.576765e+09
#
#        NUMERO DEL PRODUCTO  NUMERO DE LA AGENCIA  PLAZO UNIDAD TIEMPO  \
# count         45011.000000          45011.000000         45011.000000
# mean            117.818800            267.760481            54.726778
# min               1.000000             47.000000             2.000000
# 25%               1.000000            202.000000            12.000000
# 50%               2.000000            222.000000            72.000000
# 75%               8.000000            251.000000            72.000000
# max             906.000000            949.000000           125.000000
# std             299.974385            203.185483            28.220368
#
#        PLAZO EN DIAS  NUMERO DE PAGOS PACTA  VALOR ORIGINAL DEL PR  \
# count   45011.000000           45011.000000           4.501100e+04
# mean     1642.143520              54.460976           4.340615e+07
# min        60.000000               2.000000           1.500410e+05
# 25%       360.000000              12.000000           7.489560e+06
# 50%      2160.000000              72.000000           3.945667e+07
# 75%      2160.000000              72.000000           5.804100e+07
# max      3750.000000             123.000000           8.608890e+08
# std       845.363829              28.058475           4.371622e+07
#
#        CAPITAL PEND POR FACT  FECHA APERTURA DEL PR  ...  VLR CUOTA MES  \
# count           4.501100e+04           4.501100e+04  ...   4.501100e+04
# mean            3.105791e+07           2.022051e+07  ...   1.449325e+06
# min             0.000000e+00           2.012042e+07  ...   0.000000e+00
# 25%             1.565710e+06           2.021090e+07  ...   5.387790e+05
# 50%             2.515968e+07           2.023052e+07  ...   1.050328e+06
# 75%             4.862244e+07           2.023121e+07  ...   1.673387e+06
# max             6.110954e+08           2.025040e+07  ...   6.898513e+07
# std             3.567577e+07           2.191685e+04  ...   2.651641e+06
#
#        VLR MINIMO DE PAGO  DIA VENCIMIENTO CUOTA  NRO CUOTAS VENCIDAS  \
# count        4.501100e+04           45011.000000         18943.000000
# mean         6.438017e+06              10.405012             8.012670
# min          0.000000e+00               1.000000             1.000000
# 25%          0.000000e+00               2.000000             1.000000
# 50%          5.000000e+00               9.000000             2.000000
# 75%          2.064766e+06              17.000000             8.000000
# max          3.680392e+08              31.000000            71.000000
# std          2.324996e+07               8.510381            12.934035
#
#        NRO CUOTAS RESTANTE       ACIERTA  ANTIGÜEDAD LABORAL  \
# count         45002.000000  45011.000000        45011.000000
# mean             37.444247    584.083180           68.829153
# min               1.000000      0.000000            0.000000
# 25%               9.000000    519.000000           12.000000
# 50%              40.000000    724.000000           40.000000
# 75%              60.000000    793.000000           72.000000
# max             120.000000    947.000000        20060.000000
# std              26.663370    309.250232          298.687958
#
#        NUMERO DE PERSONAS A CARGO      INGRESOS                   FECHA_CIERRE
# count                45011.000000  4.501100e+04                          45011
# mean                     0.264269  7.789434e+06  2024-08-27 08:59:34.806158592
# min                      0.000000  0.000000e+00            2024-01-31 00:00:00
# 25%                      0.000000  2.800000e+06            2024-04-29 00:00:00
# 50%                      0.000000  5.350000e+06            2024-08-31 00:00:00
# 75%                      0.000000  9.000000e+06            2024-12-31 00:00:00
# max                     60.000000  1.022714e+09            2025-03-31 00:00:00
# std                      1.358668  2.149476e+07                            NaN
#
# [8 rows x 29 columns]

# %% [markdown]
# #### **Valores negativos**

# %%
# Selecciona solo las columnas numéricas
df_numericas = df_cartera.select_dtypes(include='number')

# Ahora sí puedes hacer la comparación sin error
columnas_con_negativos = df_numericas.columns[(df_numericas < 0).any()]
print("Columnas con valores negativos:", columnas_con_negativos.tolist())
# Out:
# Columnas con valores negativos: []

# %% [markdown]
# ### **Valores nulos por columna**

# %% [markdown]
# #### Conteo valores nulos por columna

# %%
df_cartera.isnull().sum()
# Out:
# NUMERO DE LA COLOCACION                      0
# NUMERO DE IDENTIFICACION DEUDOR              0
# NUMERO DEL PRODUCTO                          0
# NUMERO DE LA AGENCIA                         0
# PLAZO UNIDAD TIEMPO                          0
# PLAZO EN DIAS                                0
# NUMERO DE PAGOS PACTA                        0
# UNIDAD DE TIEMPO                             0
# VALOR ORIGINAL DEL PR                        0
# CAPITAL PEND POR FACT                        0
# FECHA APERTURA DEL PR                        0
# SALDO DEL PRESTAMO                           0
# NRO PLAN PAGOS VIGENT                        0
# NRO DE UTILIZACINES D                       60
# DIAS DE MORA                             26243
# CALIFICACION CARTERA                       244
# FEC CUOTA MAS ANTIG PENDIENTE DE PAGO      117
# FEC PROX PAGO                                0
# FECHA EFEC ULTIMO PAGO                    2340
# VLR ULTIMO PAGO                              0
# VLR TASA                                     0
# VLR CUOTA MES                                0
# VLR MINIMO DE PAGO                           0
# DIA VENCIMIENTO CUOTA                        0
# NRO CUOTAS VENCIDAS                      26068
# NRO CUOTAS PAGADAS                        2144
# NRO CUOTAS RESTANTE                          9
# NIVEL DE ESTUDIOS                            0
# MARCA                                        0
# TIPO DE SOLICITANTE                          0
# TIPO DE ID                                   0
# OCUPACIÓN                                    0
# ACIERTA                                      0
# TIPO DE VIVIENDA                             0
# ANTIGÜEDAD LABORAL                           0
# ESTADO CIVIL                                 0
# NUMERO DE PERSONAS A CARGO                   0
# INGRESOS                                     0
# TIPO DE VEHICULO                             0
# TIPO DE SERVICIO                             0
# PRODUCTO                                     0
# FECHA_CIERRE                                 0
# dtype: int64

# %% [markdown]
# #### Porcentaje valores nulos por columna

# %%
df_cartera.isnull().mean()
# Out:
# NUMERO DE LA COLOCACION                  0.000000
# NUMERO DE IDENTIFICACION DEUDOR          0.000000
# NUMERO DEL PRODUCTO                      0.000000
# NUMERO DE LA AGENCIA                     0.000000
# PLAZO UNIDAD TIEMPO                      0.000000
# PLAZO EN DIAS                            0.000000
# NUMERO DE PAGOS PACTA                    0.000000
# UNIDAD DE TIEMPO                         0.000000
# VALOR ORIGINAL DEL PR                    0.000000
# CAPITAL PEND POR FACT                    0.000000
# FECHA APERTURA DEL PR                    0.000000
# SALDO DEL PRESTAMO                       0.000000
# NRO PLAN PAGOS VIGENT                    0.000000
# NRO DE UTILIZACINES D                    0.001333
# DIAS DE MORA                             0.583035
# CALIFICACION CARTERA                     0.005421
# FEC CUOTA MAS ANTIG PENDIENTE DE PAGO    0.002599
# FEC PROX PAGO                            0.000000
# FECHA EFEC ULTIMO PAGO                   0.051987
# VLR ULTIMO PAGO                          0.000000
# VLR TASA                                 0.000000
# VLR CUOTA MES                            0.000000
# VLR MINIMO DE PAGO                       0.000000
# DIA VENCIMIENTO CUOTA                    0.000000
# NRO CUOTAS VENCIDAS                      0.579147
# NRO CUOTAS PAGADAS                       0.047633
# NRO CUOTAS RESTANTE                      0.000200
# NIVEL DE ESTUDIOS                        0.000000
# MARCA                                    0.000000
# TIPO DE SOLICITANTE                      0.000000
# TIPO DE ID                               0.000000
# OCUPACIÓN                                0.000000
# ACIERTA                                  0.000000
# TIPO DE VIVIENDA                         0.000000
# ANTIGÜEDAD LABORAL                       0.000000
# ESTADO CIVIL                             0.000000
# NUMERO DE PERSONAS A CARGO               0.000000
# INGRESOS                                 0.000000
# TIPO DE VEHICULO                         0.000000
# TIPO DE SERVICIO                         0.000000
# PRODUCTO                                 0.000000
# FECHA_CIERRE                             0.000000
# dtype: float64

# %% [markdown]
# ### **Valores duplicados**

# %%
df_cartera.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### **Distribución de valores por columna categórica**

# %%
for col in df_cartera.select_dtypes(include='object'):
    print(f"\n- {col}")
    print(df_cartera[col].value_counts(dropna=False).head(10))  # Top 10 categorías
# Out:
# - UNIDAD DE TIEMPO
# UNIDAD DE TIEMPO
# M    44946
# S       37
# T       15
# B       13
# Name: count, dtype: int64
#
# - CALIFICACION CARTERA
# CALIFICACION CARTERA
# A      30852
# E       4403
# B       2250
# AA      2245
# IN      2220
# D       1677
# C       1085
# NaN      244
# CC        24
# BB        11
# Name: count, dtype: int64
#
# - NRO CUOTAS PAGADAS
# NRO CUOTAS PAGADAS
# 1      2377
# 5      2343
# 3      2260
# 7      2252
# 4      2252
# 6      2183
# NaN    2144
# 2      2128
# 8      2044
# 9      1856
# Name: count, dtype: int64
#
# - NIVEL DE ESTUDIOS
# NIVEL DE ESTUDIOS
# PROFESIONAL            18941
# NO REGISTRADO           7257
# BACHILLERATO            4733
# TECNOLOGICO             4389
# TECNICO                 2948
# ESPECIALIZACION         2888
# BASICA PRIMARIA         2371
# TECNICO PROFESIONAL     1403
# MAESTRA                   60
# NO REGISTRA               21
# Name: count, dtype: int64
#
# - MARCA
# MARCA
# KIA                      22380
# NO REGISTRADO             7376
# RENAULT                   5071
# CHEVROLET                 1957
# JAC                       1881
# NISSAN                     675
# SUZUKI                     662
# FORD                       648
# MAZDA                      552
# JETOUR                     510
# Name: count, dtype: int64
#
# - TIPO DE SOLICITANTE
# TIPO DE SOLICITANTE
# EMPLEADO         19501
# INDEPENDIENTE    17441
# NO REGISTRADO     7257
# TRANSPORTADOR      672
# NO DEFINIDO         73
# TAXISTA             67
# Name: count, dtype: int64
#
# - TIPO DE ID
# TIPO DE ID
# CEDULA                                     37833
# NO REGISTRADO                               6017
# CEDULA DE EXTRANJERIA                        655
# NIT                                          446
# SOCIEDAD EXTRANJERA SIN NIT EN COLOMBIA       24
# ERROR DE REGISTRO                             21
# CARNET DIPLOMATICO                            15
# Name: count, dtype: int64
#
# - OCUPACIÓN
# OCUPACIÓN
# NO DEFINIDO                  28296
# NO REGISTRADO                 7257
# COMERCIANTE                   6183
# PROFESIONAL INDEPENDIENTE     1582
# OTRO                           994
# RENTISTA DE CAPITAL            450
# AGRO. INDUSTRIAL               249
# Name: count, dtype: int64
#
# - TIPO DE VIVIENDA
# TIPO DE VIVIENDA
# FAMILIAR       20292
# PROPIA         15037
# NO REGISTRA     7278
# ARRENDADA       2404
# Name: count, dtype: int64
#
# - ESTADO CIVIL
# ESTADO CIVIL
# UNION LIBRE      21416
# SOLTERO           9364
# NO REGISTRADO     7278
# CASADO            6319
# VIUDO              244
# SEPARADO           211
# RELIGIOSO          131
# DIVORCIADO          48
# Name: count, dtype: int64
#
# - TIPO DE VEHICULO
# TIPO DE VEHICULO
# NUEVO                30741
# OTRO                  7376
# USADO                 6631
# OPERACIÓN ANULADA      263
# Name: count, dtype: int64
#
# - TIPO DE SERVICIO
# TIPO DE SERVICIO
# PARTICULAR           31878
# OTRO                  7376
# PUBLICO               3130
# OPERACIÓN ANULADA     2627
# Name: count, dtype: int64
#
# - PRODUCTO
# PRODUCTO
# VEHICULO CONSUMO              24564
# POLIZA TODO RIESGO             5359
# CARTERA CASTIGADA              4198
# VEHICULO COMERCIAL             3746
# POLIZA ANT                     2369
# VEHICULO ALIVIO                1621
# POLIZA TODO RIESGO CASTIGO      776
# CALAMIDAD DOMESTICA             710
# VEHICULO NOVACION               601
# VEHICULO CASTIGO                466
# Name: count, dtype: int64

# %% [markdown]
# ##  **2. Analisis univariado**

# %% [markdown]
# ### **Analisis principales variables numerica**

# %%
variables = [
    'NUMERO DE PAGOS PACTA', 'VALOR ORIGINAL DEL PR', 'DIAS DE MORA',
    'NRO CUOTAS VENCIDAS', 'NRO CUOTAS PAGADAS', 'NRO CUOTAS RESTANTE',
    'EDAD DEL CLIENTE', 'VALOR COMERCIAL', 'ANTIGÜEDAD LABORAL', 'INGRESOS'
]

# %% [markdown]
# #### Frecuencia principales variables numericas

# %%
import math
import matplotlib.pyplot as plt
import seaborn as sns

# Seleccionar solo columnas numéricas
variables = df_cartera.select_dtypes(include='number').columns

# Configuración de la cuadrícula
cols = 3
total = len(variables)
rows = math.ceil(total / cols)

# Tamaño de la figura ajustado a la cantidad de subplots
plt.figure(figsize=(5 * cols, 4 * rows))

# Graficar cada variable
for i, col in enumerate(variables):
    plt.subplot(rows, cols, i + 1)
    sns.histplot(df_cartera[col].dropna(), bins=30, kde=False)
    plt.title(col)
    plt.xlabel("")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Valor atipicos

# %%
outlier_details = {}

for var in variables:
    data = df_cartera[var].dropna()
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = max(Q1 - 1.5 * IQR, 0)  # corregido para evitar negativos
    upper_bound = Q3 + 1.5 * IQR

    lower_outliers = data[data < lower_bound]
    upper_outliers = data[data > upper_bound]

    outlier_details[var] = {
        "Total": len(data),
        "Outliers inferiores": len(lower_outliers),
        "Outliers superiores": len(upper_outliers),
        "% Inferiores": round(len(lower_outliers) / len(data) * 100, 2),
        "% Superiores": round(len(upper_outliers) / len(data) * 100, 2),
        "Limite inferior": lower_bound,
        "Limite superior": upper_bound
    }

outlier_stats = pd.DataFrame(outlier_details).T
print(outlier_stats)
# Out:
#                         Total  Outliers inferiores  Outliers superiores  \
# NUMERO DE PAGOS PACTA  2960.0                  0.0                 20.0
# VALOR ORIGINAL DEL PR  2960.0                  0.0                102.0
# DIAS DE MORA           2960.0                  0.0                632.0
# NRO CUOTAS VENCIDAS    2960.0                  0.0                426.0
# NRO CUOTAS PAGADAS     2845.0                  0.0                 54.0
# NRO CUOTAS RESTANTE    2960.0                  0.0                  0.0
# EDAD DEL CLIENTE       2819.0                  0.0                  6.0
# VALOR COMERCIAL        2012.0                  0.0                 65.0
# ANTIGÜEDAD LABORAL     2960.0                  0.0                250.0
# INGRESOS               2960.0                  0.0                164.0
#
#                        % Inferiores  % Superiores  Limite inferior  \
# NUMERO DE PAGOS PACTA           0.0          0.68              0.0
# VALOR ORIGINAL DEL PR           0.0          3.45              0.0
# DIAS DE MORA                    0.0         21.35              0.0
# NRO CUOTAS VENCIDAS             0.0         14.39              0.0
# NRO CUOTAS PAGADAS              0.0          1.90              0.0
# NRO CUOTAS RESTANTE             0.0          0.00              0.0
# EDAD DEL CLIENTE                0.0          0.21             10.0
# VALOR COMERCIAL                 0.0          3.23              0.0
# ANTIGÜEDAD LABORAL              0.0          8.45              0.0
# INGRESOS                        0.0          5.54              0.0
#
#                        Limite superior
# NUMERO DE PAGOS PACTA     1.158750e+02
# VALOR ORIGINAL DEL PR     1.232657e+08
# DIAS DE MORA              1.425000e+02
# NRO CUOTAS VENCIDAS       5.000000e+00
# NRO CUOTAS PAGADAS        6.350000e+01
# NRO CUOTAS RESTANTE       1.350000e+02
# EDAD DEL CLIENTE          7.400000e+01
# VALOR COMERCIAL           1.584162e+08
# ANTIGÜEDAD LABORAL        1.593750e+02
# INGRESOS                  2.021438e+07

# %%
# Boxplots para cada variable
plt.figure(figsize=(20, 20))
for i, col in enumerate(variables):
    plt.subplot(4, 3, i + 1)
    sns.boxplot(x=df_cartera[col].dropna())
    plt.title(f'Boxplot - {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Analisis principales variables categoricas**

# %%
# Variables categóricas adicionales que quieres analizar
categorical_vars = [
    'SEXO', 'PERFIL DEL TITULAR', 'MARCA', 'CLASE', 'MODELO',
    'NIVEL DE ESTUDIOS', 'TIPO DE SOLICITANTE', 'OCUPACIÓN',
    'TIPO DE VIVIENDA', 'ESTADO CIVIL.1', 'TIPO DE VEHICULO', 'CREDITO EN MORA'
]

# %%
# Gráficos de barras tipo histograma para cada variable
plt.figure(figsize=(20, 25))
for i, col in enumerate(categorical_vars):
    plt.subplot(5, 3, i + 1)
    order = df_cartera[col].value_counts().head(10).index  # Mostrar solo las 10 categorías más frecuentes
    sns.countplot(data=df_cartera, y=col, order=order)
    plt.title(f'Distribución de {col}')
    plt.xlabel('Frecuencia')
    plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  **3. Analisis Bivariado**

# %%
# Variables categóricas a analizar
categorical_vars = [
    'SEXO', 'PERFIL DEL TITULAR', 'CLASE', 'MODELO',
    'NIVEL DE ESTUDIOS', 'TIPO DE SOLICITANTE', 'OCUPACIÓN',
    'TIPO DE VIVIENDA', 'ESTADO CIVIL.1', 'TIPO DE VEHICULO'
]

# Crear gráficos bivariados
plt.figure(figsize=(20, 30))
plot_idx = 1

for col in categorical_vars:
    prop_df = pd.crosstab(df_cartera[col], df_cartera['CREDITO EN MORA'], normalize='index') * 100
    valid_cols = [c for c in ['1', '0'] if c in prop_df.columns]
    
    if len(valid_cols) == 0:
        continue  # Saltar si no hay datos válidos


    ax = plt.subplot(6, 2, plot_idx)
    colors = ['red' if c == '1' else 'green' for c in valid_cols]
    prop_df[valid_cols].plot(kind='bar', stacked=True, ax=ax, color=colors, legend=False)
    
    plt.title(f'% de Mora por categoría de {col}')
    plt.ylabel('%')
    plt.xlabel('')
    plt.xticks(rotation=45)
    plot_idx += 1

plt.tight_layout()
plt.legend(title='CREDITO EN MORA', labels=['En mora', 'Sin mora'], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
